# %% [markdown]
# 구글 드라이브 마운트하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/MyDrive/2022_CV/NetVLAD')

# !pip install faiss-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      |████████████████████████████████| 85.5 MB 107 kB/s
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
cd /content/drive/My Drive/2022_CV/NetVLAD
# Out:
# /content/drive/My Drive/2022_CV/NetVLAD

# %%
ls -al
# Out:
# total 86044
# -rw------- 1 root root    29840 Aug  7  2021 berlin.mat
# drwx------ 2 root root     4096 Sep 27  2021 ckpt/
# -rw------- 1 root root   138659 Jun 17 17:14 idea_submit2.json
# -rw------- 1 root root   139098 Jun 17 16:01 idea_submit.json
# -rw------- 1 root root    99496 Jun 17 17:32 NetVLAD_add_idea2_code.ipynb
# -rw------- 1 root root   115082 Jun 17 16:08 NetVLAD_add_idea_code.ipynb
# -rw------- 1 root root   118749 Jun 17 07:03 NetVLAD_base_code.ipynb
# -rw------- 1 root root 87315062 Sep 26  2021 pittsburgh_checkpoint.pth.tar
# drwx------ 2 root root     4096 Sep 27  2021 Query_resized/
# drwx------ 2 root root     4096 Sep 27  2021 Reference_resized/
# -rw------- 1 root root   138889 Jun 17 07:02 submit.json

# %% [markdown]
# 할당받은 GPU 체크하기

# %%
# !nvidia-smi
# Out:
# Fri Jun 17 17:33:19 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision

from torchvision.models import resnet18,vgg16

torch.manual_seed(777)

# %% [markdown]
# Loss 평균값 계산을 위한 클래스 정의

# %%
class AverageMeter(object):
    """
    Keeps track of most recent, average, sum, and count of a metric.
    """

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# NetVLAD 아키텍처
#
# - 해당 코드는 'https://github.com/Nanne/pytorch-NetVlad/'를 베이스로 만들어짐

# %%
class NetVLAD(nn.Module):
    """NetVLAD layer implementation"""

    def __init__(self, num_clusters=12, dim=128, alpha=100.0,normalize_input=True):
        """
        Args:
            num_clusters : int
                The number of clusters
            dim : int
                Dimension of descriptors
            alpha : float
                Parameter of initialization. Larger value is harder assignment.
            normalize_input : bool
                If true, descriptor-wise L2 normalization is applied to input.
        """
        super(NetVLAD, self).__init__()
        self.num_clusters = num_clusters
        self.dim = dim
        self.alpha = alpha
        self.normalize_input = normalize_input
        self.conv = nn.Conv2d(dim, num_clusters, kernel_size=(1, 1), bias=False)
        self.centroids = nn.Parameter(torch.rand(num_clusters, dim))
        self._init_params()


    def _init_params(self):
        self.conv.weight = nn.Parameter(
            (2.0 * self.alpha * self.centroids).unsqueeze(-1).unsqueeze(-1)
        )

    def forward(self, x):

        N, C = x.shape[:2]

        if self.normalize_input:
            x = F.normalize(x, p=2, dim=1)  # across descriptor dim

        # soft-assignment
        soft_assign = self.conv(x).view(N, self.num_clusters, -1)
        soft_assign = F.softmax(soft_assign, dim=1)

        x_flatten = x.view(N, C, -1)
        
        # calculate residuals to each clusters
        vlad = torch.zeros([N, self.num_clusters, C], dtype=x.dtype, layout=x.layout, device=x.device)
        for C in range(self.num_clusters): # slower than non-looped, but lower memory usage 
            residual = x_flatten.unsqueeze(0).permute(1, 0, 2, 3) - \
                    self.centroids[C:C+1, :].expand(x_flatten.size(-1), -1, -1).permute(1, 2, 0).unsqueeze(0)
            residual *= soft_assign[:,C:C+1,:].unsqueeze(2)
            vlad[:,C:C+1,:] = residual.sum(dim=-1)

        vlad = F.normalize(vlad, p=2, dim=2)  # intra-normalization
        vlad = vlad.view(x.size(0), -1)  # flatten
        vlad = F.normalize(vlad, p=2, dim=1)  # L2 normalize

        return vlad

# %% [markdown]
# 모델 아키텍처 구축
#
# ![image.png](data:image/png;base64,...)
#
# - 백본 : VGG16
# - Pooling : NetVLAD

# %%
# VGG 16
encoder = vgg16(pretrained=True)
layers = list(encoder.features.children())[:-2]

for l in layers[:-5]: 
    for p in l.parameters():
        p.requires_grad = False

model = nn.Module() 

encoder = nn.Sequential(*layers)
model.add_module('encoder', encoder)

dim = list(encoder.parameters())[-1].shape[0]  # last channels (512)

# Define model for embedding
net_vlad = NetVLAD(num_clusters=16, dim=dim)
model.add_module('pool', net_vlad)

model = model.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
# Pretrained Model Load(Pittsburgh 30k)
# NetVLAD는 피츠버그 데이터셋을 이용해 학습하였음, 하지만 데이터셋의 용량이 크고 학습에 필요한 하드웨어 리소스 문제로 본 챌린지에서는 사전학습된 체크포인트를 제공함

load_model = torch.load('./pittsburgh_checkpoint.pth.tar')
model.load_state_dict(load_model['state_dict'])
# Out:
# <All keys matched successfully>

# %%
class add_module(nn.Module):
    """add_module layer implementation"""

    def __init__(self):
        super(add_module, self).__init__()

        self.maxpool = nn.MaxPool2d((16,16))
        self.conv = nn.Conv2d(515,512,kernel_size=(1,1),bias=False)

    def _init_params(self):
        nn.init.kaiming_uniform_(self.conv.weight, a=math.sqrt(5))

    def forward(self, img, x):

      # # import pdb;pdb.set_trace()
        img = img.squeeze(0)
        img_f = self.maxpool(img).cuda()
        x = torch.cat((x, img_f), 1)
        x = self.conv(x)
        return x

# %%
middle = add_module()

model.add_module('middle',middle)

# %%
model.cuda()
# Out:
# Module(
#   (encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (pool): NetVLAD(
#     (conv): Conv2d(512, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (middle): add_module(
#     (maxpool): MaxPool2d(kernel_size=(16, 16), stride=(16, 16), padding=0, dilation=1, ceil_mode=False)
#     (conv): Conv2d(515, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# 본 챌린지에서 사용하는 'Berlin Kudamm Dataset' 로더

# %%
import torch.utils.data as data
import torchvision.transforms as transforms

from random import choice
from os.path import join, exists
from collections import namedtuple
from scipy.io import loadmat
from PIL import Image
from sklearn.neighbors import NearestNeighbors

root_dir = '/content/drive/My Drive/2022_CV/NetVLAD' # 필요시 경로수정

def parse_dbStruct(path):
    mat = loadmat(path)

    matStruct = mat['dbStruct'][0]

    dataset = 'dataset'

    whichSet = 'VPR'

    dbImage = matStruct[0]
    locDb = matStruct[1]

    qImage = matStruct[2]
    locQ = matStruct[3]

    numDb = matStruct[4].item()
    numQ = matStruct[5].item()

    posDistThr = matStruct[6].item()
    posDistSqThr = matStruct[7].item()

    return dbStruct(whichSet, dataset, dbImage, locDb, qImage, 
            locQ, numDb, numQ, posDistThr, 
            posDistSqThr)
  
dbStruct = namedtuple('dbStruct', ['whichSet', 'dataset',
  'dbImage', 'locDb', 'qImage', 'locQ', 'numDb', 'numQ',
  'posDistThr', 'posDistSqThr'])
  
class BerlinDataset(data.Dataset) :
  
  def __init__(self,condition='train') :
    self.dbStruct = parse_dbStruct('/content/drive/My Drive/2022_CV/NetVLAD/berlin.mat') # 필요시 경로수정
    self.input_transform = transforms.Compose([
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                            std=[0.229, 0.224, 0.225]),
      ])
    
    self.condition = condition

    if self.condition == 'train' :
      self.images = [join(root_dir, dbIm.replace(' ','')) for dbIm in self.dbStruct.dbImage]
    elif self.condition == 'test' :
      self.images = [join(root_dir, qIm.replace(' ','')) for qIm in self.dbStruct.qImage]
    else :
      self.images = [join(root_dir, dbIm.replace(' ','')) for dbIm in self.dbStruct.dbImage]
    
    self.positives = None
    self.distances = None

    self.getPositives()
  
  def __getitem__(self, index):

      if self.condition == 'train' :
        img = Image.open(self.images[index])
        img = self.input_transform(img)

        pos_list = self.positives[index].tolist()
        pos_list.remove(index)
        pos_index = self.positives[index][np.random.randint(0,len(self.positives[index]))]
        pos_img = Image.open(self.images[pos_index])
        pos_img = self.input_transform(pos_img)

        pos_list = pos_list + [index]
        neg_index = choice([i for i in range(len(self.images)) if i not in pos_list])
        neg_img = Image.open(self.images[neg_index])
        neg_img = self.input_transform(neg_img)

        img = torch.stack([img,pos_img,neg_img],dim=0)
        label = torch.Tensor([0, 0, 1])

        return img, label

      elif self.condition == 'test' :
        img = Image.open(self.images[index])
        img = self.input_transform(img)

        return img
      
      else :
        img = Image.open(self.images[index])
        img = self.input_transform(img)

        return img


  def __len__(self):
      return len(self.images)

  def getPositives(self):
      # positives for evaluation are those within trivial threshold range
      #fit NN to find them, search by radius
      if  self.condition == 'train' :
          knn = NearestNeighbors(n_jobs=1)
          knn.fit(self.dbStruct.locDb)

          self.distances, self.positives = knn.radius_neighbors(self.dbStruct.locDb,radius=self.dbStruct.posDistThr)
      else :
          knn = NearestNeighbors(n_jobs=1)
          knn.fit(self.dbStruct.locDb)

          self.distances, self.positives = knn.radius_neighbors(self.dbStruct.locQ,
                  radius=self.dbStruct.posDistThr)
      
      return self.positives

# %%
train_dataset = BerlinDataset(condition="train")
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1,shuffle=True,num_workers=0)

# %% [markdown]
# 피츠버그 데이터셋기반 사전학습된 weight를 Berlin Kudamm 데이터셋 finetune

# %%
epochs = 100
global_batch_size = 8
lr = 0.00001
momentum = 0.9
weightDecay = 0.001
losses = AverageMeter()
best_loss = 100.0
margin = 0.1 

criterion = nn.TripletMarginLoss(margin=margin**0.5, p=2, reduction='sum').cuda()
optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=lr, momentum=momentum, weight_decay=weightDecay)

model.train()

for epoch in range(epochs):
  for batch_idx, (train_image,train_label) in enumerate(train_loader) :
    # import pdb;pdb.set_trace()
    output_train = model.encoder(train_image.squeeze().cuda())
    output_train = model.middle(train_image,output_train)
    output_train = model.pool(output_train)
    triplet_loss = criterion(output_train[0].reshape(1,-1),output_train[1].reshape(1,-1),output_train[2].reshape(1,-1))

    if batch_idx == 0 :
      optimizer.zero_grad()

    triplet_loss.backward(retain_graph=True)
    losses.update(triplet_loss.item())

    if (batch_idx +1) % global_batch_size == 0 :
      for name, p in model.named_parameters():
        if p.requires_grad:
          p.grad /= global_batch_size
    
        optimizer.step()
        optimizer.zero_grad()

    if batch_idx % 20 == 0 and batch_idx != 0:
      print('epoch : {}, batch_idx  : {}, triplet_loss : {}'.format(epoch,batch_idx,losses.avg))
  
  if best_loss > losses.avg :
    best_save_name = 'best_model.pt'
    best_path = F"./ckpt/idea/2_{best_save_name}" 
    torch.save(model.state_dict(), best_path)
    
  model_save_name = 'model_{:02d}.pt'.format(epoch)
  path = F"./ckpt/idea/2_{model_save_name}" 
  torch.save(model.state_dict(), path)
# Out:
# epoch : 0, batch_idx  : 20, triplet_loss : 0.2694619745016098
# epoch : 0, batch_idx  : 40, triplet_loss : 0.2665075892355384
# epoch : 0, batch_idx  : 60, triplet_loss : 0.278458515640165
# epoch : 0, batch_idx  : 80, triplet_loss : 0.2771626990518452
# epoch : 0, batch_idx  : 100, triplet_loss : 0.2744188146425946
# epoch : 0, batch_idx  : 120, triplet_loss : 0.27849816327745264
# epoch : 0, batch_idx  : 140, triplet_loss : 0.2788562926840275
# epoch : 0, batch_idx  : 160, triplet_loss : 0.27730626487954063
# epoch : 0, batch_idx  : 180, triplet_loss : 0.2778437355769932
# epoch : 0, batch_idx  : 200, triplet_loss : 0.2792610652855973
# epoch : 0, batch_idx  : 220, triplet_loss : 0.27904720799955307
# epoch : 0, batch_idx  : 240, triplet_loss : 0.2775647846123984
# epoch : 0, batch_idx  : 260, triplet_loss : 0.27722437948102696
# epoch : 0, batch_idx  : 280, triplet_loss : 0.2780588873764798
# epoch : 0, batch_idx  : 300, triplet_loss : 0.2774392070861354
# epoch : 1, batch_idx  : 20, triplet_loss : 0.27596657311738426
# epoch : 1, batch_idx  : 40, triplet_loss : 0.2750231734044115
# epoch : 1, batch_idx  : 60, triplet_loss : 0.27372512968381246
# epoch : 1, batch_idx  : 80, triplet_loss : 0.27334044364434257
# epoch : 1, batch_idx  : 100, triplet_loss : 0.2732936670981258
# epoch : 1, batch_idx  : 120, triplet_loss : 0.27274339640962664
# epoch : 1, batch_idx  : 140, triplet_loss : 0.2724861401778001
# epoch : 1, batch_idx  : 160, triplet_loss : 0.27301456981583644
# epoch : 1, batch_idx  : 180, triplet_loss : 0.2723510341812866
# epoch : 1, batch_idx  : 200, triplet_loss : 0.2723999222794783
# epoch : 1, batch_idx  : 220, triplet_loss : 0.2726225294520922
# epoch : 1, batch_idx  : 240, triplet_loss : 0.2719362098085988
# epoch : 1, batch_idx  : 260, triplet_loss : 0.2729905704830004
# epoch : 1, batch_idx  : 280, triplet_loss : 0.2738368431059252
# epoch : 1, batch_idx  : 300, triplet_loss : 0.2732586079981269
# epoch : 2, batch_idx  : 20, triplet_loss : 0.27322493785151347
# epoch : 2, batch_idx  : 40, triplet_loss : 0.2723129987939413
# epoch : 2, batch_idx  : 60, triplet_loss : 0.27201974856922695
# epoch : 2, batch_idx  : 80, triplet_loss : 0.27232739110759685
# epoch : 2, batch_idx  : 100, triplet_loss : 0.2719151362143099
# epoch : 2, batch_idx  : 120, triplet_loss : 0.2721573823244772
# epoch : 2, batch_idx  : 140, triplet_loss : 0.27188094861330697
# epoch : 2, batch_idx  : 160, triplet_loss : 0.2719299915247846
# epoch : 2, batch_idx  : 180, triplet_loss : 0.2713348069798077
# epoch : 2, batch_idx  : 200, triplet_loss : 0.2701620234691047
# epoch : 2, batch_idx  : 220, triplet_loss : 0.27013994263675944
# epoch : 2, batch_idx  : 240, triplet_loss : 0.2698646619555865
# epoch : 2, batch_idx  : 260, triplet_loss : 0.26967669716702003
# epoch : 2, batch_idx  : 280, triplet_loss : 0.2696148606285666
# epoch : 2, batch_idx  : 300, triplet_loss : 0.2699116837670395
# epoch : 3, batch_idx  : 20, triplet_loss : 0.27010598099429783
# epoch : 3, batch_idx  : 40, triplet_loss : 0.2698779069455691
# epoch : 3, batch_idx  : 60, triplet_loss : 0.2688695627040901
# epoch : 3, batch_idx  : 80, triplet_loss : 0.2692082466472046
# epoch : 3, batch_idx  : 100, triplet_loss : 0.26872633837613485
# epoch : 3, batch_idx  : 120, triplet_loss : 0.26885639330125144
# epoch : 3, batch_idx  : 140, triplet_loss : 0.26927306201044104
# epoch : 3, batch_idx  : 160, triplet_loss : 0.26921747149333886
# epoch : 3, batch_idx  : 180, triplet_loss : 0.26869229579598164
# epoch : 3, batch_idx  : 200, triplet_loss : 0.2683202424204777
# epoch : 3, batch_idx  : 220, triplet_loss : 0.26746768066827736
# epoch : 3, batch_idx  : 240, triplet_loss : 0.26757746399557397
# epoch : 3, batch_idx  : 260, triplet_loss : 0.26759052343499334
# epoch : 3, batch_idx  : 280, triplet_loss : 0.2671420407387826
# epoch : 3, batch_idx  : 300, triplet_loss : 0.2668760814018434
# epoch : 4, batch_idx  : 20, triplet_loss : 0.26674135314036646
# epoch : 4, batch_idx  : 40, triplet_loss : 0.2665549034716629
# epoch : 4, batch_idx  : 60, triplet_loss : 0.26664878016135507
# epoch : 4, batch_idx  : 80, triplet_loss : 0.26677693834524147
# epoch : 4, batch_idx  : 100, triplet_loss : 0.2665545573854763
# epoch : 4, batch_idx  : 120, triplet_loss : 0.2666864972358695
# epoch : 4, batch_idx  : 140, triplet_loss : 0.2664778751821798
# epoch : 4, batch_idx  : 160, triplet_loss : 0.2662100541440214
# epoch : 4, batch_idx  : 180, triplet_loss : 0.26558806809934377
# epoch : 4, batch_idx  : 200, triplet_loss : 0.2647236122218566
# epoch : 4, batch_idx  : 220, triplet_loss : 0.26449929580304293
# epoch : 4, batch_idx  : 240, triplet_loss : 0.26403594843212097
# epoch : 4, batch_idx  : 260, triplet_loss : 0.26387706012928575
# epoch : 4, batch_idx  : 280, triplet_loss : 0.26418070937219035
# epoch : 4, batch_idx  : 300, triplet_loss : 0.2640485679617124
# epoch : 5, batch_idx  : 20, triplet_loss : 0.26386557887516104
# epoch : 5, batch_idx  : 40, triplet_loss : 0.2637764454479916
# epoch : 5, batch_idx  : 60, triplet_loss : 0.2634392126088198
# epoch : 5, batch_idx  : 80, triplet_loss : 0.26366273540753005
# epoch : 5, batch_idx  : 100, triplet_loss : 0.26345554376740005
# epoch : 5, batch_idx  : 120, triplet_loss : 0.2629520925877716
# epoch : 5, batch_idx  : 140, triplet_loss : 0.26251517712617045
# epoch : 5, batch_idx  : 160, triplet_loss : 0.26215318507331425
# epoch : 5, batch_idx  : 180, triplet_loss : 0.26228380806612195
# epoch : 5, batch_idx  : 200, triplet_loss : 0.2623578678461066
# epoch : 5, batch_idx  : 220, triplet_loss : 0.26240919955544867
# epoch : 5, batch_idx  : 240, triplet_loss : 0.2623847016950525
# epoch : 5, batch_idx  : 260, triplet_loss : 0.262725191281377
# epoch : 5, batch_idx  : 280, triplet_loss : 0.2630155519464092
# epoch : 5, batch_idx  : 300, triplet_loss : 0.2628556133463445
# epoch : 6, batch_idx  : 20, triplet_loss : 0.26266289358063943
# epoch : 6, batch_idx  : 40, triplet_loss : 0.26231595996138335
# epoch : 6, batch_idx  : 60, triplet_loss : 0.2616138937157653
# epoch : 6, batch_idx  : 80, triplet_loss : 0.2616412259164354
# epoch : 6, batch_idx  : 100, triplet_loss : 0.26144649863092967
# epoch : 6, batch_idx  : 120, triplet_loss : 0.2615266627578664
# epoch : 6, batch_idx  : 140, triplet_loss : 0.2618890349953263
# epoch : 6, batch_idx  : 160, triplet_loss : 0.2618704350624224
# epoch : 6, batch_idx  : 180, triplet_loss : 0.2611378407795839
# epoch : 6, batch_idx  : 200, triplet_loss : 0.26078093307052586
# epoch : 6, batch_idx  : 220, triplet_loss : 0.26040848184934423
# epoch : 6, batch_idx  : 240, triplet_loss : 0.25987016240989463
# epoch : 6, batch_idx  : 260, triplet_loss : 0.2595324758257899
# epoch : 6, batch_idx  : 280, triplet_loss : 0.2594168075306586
# epoch : 6, batch_idx  : 300, triplet_loss : 0.2590303573373799
# epoch : 7, batch_idx  : 20, triplet_loss : 0.25861110083285405
# epoch : 7, batch_idx  : 40, triplet_loss : 0.2585902924434369
# epoch : 7, batch_idx  : 60, triplet_loss : 0.25856622687453135
# epoch : 7, batch_idx  : 80, triplet_loss : 0.25850250592562335
# epoch : 7, batch_idx  : 100, triplet_loss : 0.2583386983014335
# epoch : 7, batch_idx  : 120, triplet_loss : 0.2582344348868094
# epoch : 7, batch_idx  : 140, triplet_loss : 0.25804302639791016
# epoch : 7, batch_idx  : 160, triplet_loss : 0.2576258864037411
# epoch : 7, batch_idx  : 180, triplet_loss : 0.2572187148520003
# epoch : 7, batch_idx  : 200, triplet_loss : 0.2571889238463883
# epoch : 7, batch_idx  : 220, triplet_loss : 0.2571063385972212
# epoch : 7, batch_idx  : 240, triplet_loss : 0.2569964229877291
# epoch : 7, batch_idx  : 260, triplet_loss : 0.2569509184835596
# epoch : 7, batch_idx  : 280, triplet_loss : 0.25708834643612083
# epoch : 7, batch_idx  : 300, triplet_loss : 0.25681713403535394
# epoch : 8, batch_idx  : 20, triplet_loss : 0.25628939839841064
# epoch : 8, batch_idx  : 40, triplet_loss : 0.2561048231274765
# epoch : 8, batch_idx  : 60, triplet_loss : 0.25564273590134406
# epoch : 8, batch_idx  : 80, triplet_loss : 0.25555182337714955
# epoch : 8, batch_idx  : 100, triplet_loss : 0.25517715368287297
# epoch : 8, batch_idx  : 120, triplet_loss : 0.2549075805106364
# epoch : 8, batch_idx  : 140, triplet_loss : 0.2548528978375727
# epoch : 8, batch_idx  : 160, triplet_loss : 0.25450527219793745
# epoch : 8, batch_idx  : 180, triplet_loss : 0.25473542779274605
# epoch : 8, batch_idx  : 200, triplet_loss : 0.25461061776694976
# epoch : 8, batch_idx  : 220, triplet_loss : 0.25447755874817163
# epoch : 8, batch_idx  : 240, triplet_loss : 0.254147203568108
# epoch : 8, batch_idx  : 260, triplet_loss : 0.25399803645100094
# epoch : 8, batch_idx  : 280, triplet_loss : 0.254076142993786
# epoch : 8, batch_idx  : 300, triplet_loss : 0.2542107772602545
# epoch : 9, batch_idx  : 20, triplet_loss : 0.25359873528601123
# epoch : 9, batch_idx  : 40, triplet_loss : 0.25364154373514225
# epoch : 9, batch_idx  : 60, triplet_loss : 0.2538315114066144
# epoch : 9, batch_idx  : 80, triplet_loss : 0.2535959414991678
# epoch : 9, batch_idx  : 100, triplet_loss : 0.2535330183246578
# epoch : 9, batch_idx  : 120, triplet_loss : 0.2537269945675776
# epoch : 9, batch_idx  : 140, triplet_loss : 0.25373444648194
# epoch : 9, batch_idx  : 160, triplet_loss : 0.25389709480039485
# epoch : 9, batch_idx  : 180, triplet_loss : 0.2535360547090473
# epoch : 9, batch_idx  : 200, triplet_loss : 0.2531166575531539
# epoch : 9, batch_idx  : 220, triplet_loss : 0.2526828552029897
# epoch : 9, batch_idx  : 240, triplet_loss : 0.252559034991311
# epoch : 9, batch_idx  : 260, triplet_loss : 0.25242875256235636
# epoch : 9, batch_idx  : 280, triplet_loss : 0.2523640890740335
# epoch : 9, batch_idx  : 300, triplet_loss : 0.2521308550618882
# epoch : 10, batch_idx  : 20, triplet_loss : 0.25173204315119774
# epoch : 10, batch_idx  : 40, triplet_loss : 0.25145389941157653
# epoch : 10, batch_idx  : 60, triplet_loss : 0.25126560014678107
# epoch : 10, batch_idx  : 80, triplet_loss : 0.2511111892174579
# epoch : 10, batch_idx  : 100, triplet_loss : 0.2508333287363029
# epoch : 10, batch_idx  : 120, triplet_loss : 0.25109546308738984
# epoch : 10, batch_idx  : 140, triplet_loss : 0.25094900052473335
# epoch : 10, batch_idx  : 160, triplet_loss : 0.250783124906444
# epoch : 10, batch_idx  : 180, triplet_loss : 0.2503499904559413
# epoch : 10, batch_idx  : 200, triplet_loss : 0.25029728496745474
# epoch : 10, batch_idx  : 220, triplet_loss : 0.25040498092588803
# epoch : 10, batch_idx  : 240, triplet_loss : 0.25017959117907035
# epoch : 10, batch_idx  : 260, triplet_loss : 0.25006040448355205
# epoch : 10, batch_idx  : 280, triplet_loss : 0.25019536298274714
# epoch : 10, batch_idx  : 300, triplet_loss : 0.2498489141862637
# epoch : 11, batch_idx  : 20, triplet_loss : 0.24977326376832645
# epoch : 11, batch_idx  : 40, triplet_loss : 0.24952605131358035
# epoch : 11, batch_idx  : 60, triplet_loss : 0.24952645891930267
# epoch : 11, batch_idx  : 80, triplet_loss : 0.24935800036075598
# epoch : 11, batch_idx  : 100, triplet_loss : 0.2491114489220701
# epoch : 11, batch_idx  : 120, triplet_loss : 0.24916352054039081
# epoch : 11, batch_idx  : 140, triplet_loss : 0.2489373974781872
# epoch : 11, batch_idx  : 160, triplet_loss : 0.24861060937410567
# epoch : 11, batch_idx  : 180, triplet_loss : 0.24847771179807235
# epoch : 11, batch_idx  : 200, triplet_loss : 0.24830226448916215
# epoch : 11, batch_idx  : 220, triplet_loss : 0.24822732236920572
# epoch : 11, batch_idx  : 240, triplet_loss : 0.24821597119145528
# epoch : 11, batch_idx  : 260, triplet_loss : 0.24797480882898795
# epoch : 11, batch_idx  : 280, triplet_loss : 0.24791400326463273
# epoch : 11, batch_idx  : 300, triplet_loss : 0.2474030501396456
# epoch : 12, batch_idx  : 20, triplet_loss : 0.24712591871371462
# epoch : 12, batch_idx  : 40, triplet_loss : 0.24715120160507698
# epoch : 12, batch_idx  : 60, triplet_loss : 0.24715779529878135
# epoch : 12, batch_idx  : 80, triplet_loss : 0.2472028430443858
# epoch : 12, batch_idx  : 100, triplet_loss : 0.24736879401642645
# epoch : 12, batch_idx  : 120, triplet_loss : 0.24712755918640747
# epoch : 12, batch_idx  : 140, triplet_loss : 0.24710222673510676
# epoch : 12, batch_idx  : 160, triplet_loss : 0.2467609514418556
# epoch : 12, batch_idx  : 180, triplet_loss : 0.24682080990968097
# epoch : 12, batch_idx  : 200, triplet_loss : 0.24653900242566643
# epoch : 12, batch_idx  : 220, triplet_loss : 0.24640601787479877
# epoch : 12, batch_idx  : 240, triplet_loss : 0.24608500815888953
# epoch : 12, batch_idx  : 260, triplet_loss : 0.2458949122040702
# epoch : 12, batch_idx  : 280, triplet_loss : 0.24557048557834527
# epoch : 12, batch_idx  : 300, triplet_loss : 0.2451707821208448
# epoch : 13, batch_idx  : 20, triplet_loss : 0.24472365131210821
# epoch : 13, batch_idx  : 40, triplet_loss : 0.24441176650739832
# epoch : 13, batch_idx  : 60, triplet_loss : 0.24432538684629285
# epoch : 13, batch_idx  : 80, triplet_loss : 0.24393762572579678
# epoch : 13, batch_idx  : 100, triplet_loss : 0.2437927539257977
# epoch : 13, batch_idx  : 120, triplet_loss : 0.24352215712988856
# epoch : 13, batch_idx  : 140, triplet_loss : 0.24324827045449254
# epoch : 13, batch_idx  : 160, triplet_loss : 0.24310887891701755
# epoch : 13, batch_idx  : 180, triplet_loss : 0.24294090451362013
# epoch : 13, batch_idx  : 200, triplet_loss : 0.24308237203462307
# epoch : 13, batch_idx  : 220, triplet_loss : 0.2427441482035027
# epoch : 13, batch_idx  : 240, triplet_loss : 0.24262376874857636
# epoch : 13, batch_idx  : 260, triplet_loss : 0.24249982644466933
# epoch : 13, batch_idx  : 280, triplet_loss : 0.2424172077216114
# epoch : 13, batch_idx  : 300, triplet_loss : 0.2423045810107197
# epoch : 14, batch_idx  : 20, triplet_loss : 0.24199345363786864
# epoch : 14, batch_idx  : 40, triplet_loss : 0.24172067099496644
# epoch : 14, batch_idx  : 60, triplet_loss : 0.24139873048556823
# epoch : 14, batch_idx  : 80, triplet_loss : 0.2412790500055287
# epoch : 14, batch_idx  : 100, triplet_loss : 0.24109266957150902
# epoch : 14, batch_idx  : 120, triplet_loss : 0.2409674258346391
# epoch : 14, batch_idx  : 140, triplet_loss : 0.24070531939432857
# epoch : 14, batch_idx  : 160, triplet_loss : 0.24041307204997092
# epoch : 14, batch_idx  : 180, triplet_loss : 0.24058548331924837
# epoch : 14, batch_idx  : 200, triplet_loss : 0.24068497174494624
# epoch : 14, batch_idx  : 220, triplet_loss : 0.24069436026169466
# epoch : 14, batch_idx  : 240, triplet_loss : 0.24057615416135308
# epoch : 14, batch_idx  : 260, triplet_loss : 0.240486653076494
# epoch : 14, batch_idx  : 280, triplet_loss : 0.24033436193498303
# epoch : 14, batch_idx  : 300, triplet_loss : 0.24007810801997295
# epoch : 15, batch_idx  : 20, triplet_loss : 0.23982198428046853
# epoch : 15, batch_idx  : 40, triplet_loss : 0.23956266286134267
# epoch : 15, batch_idx  : 60, triplet_loss : 0.23949196467769893
# epoch : 15, batch_idx  : 80, triplet_loss : 0.23938207952544774
# epoch : 15, batch_idx  : 100, triplet_loss : 0.2391917252368378
# epoch : 15, batch_idx  : 120, triplet_loss : 0.23919155058333208
# epoch : 15, batch_idx  : 140, triplet_loss : 0.23892297930715994
# epoch : 15, batch_idx  : 160, triplet_loss : 0.23880243344525737
# epoch : 15, batch_idx  : 180, triplet_loss : 0.23847907894936302
# epoch : 15, batch_idx  : 200, triplet_loss : 0.23831549423990073
# epoch : 15, batch_idx  : 220, triplet_loss : 0.2382086272523505
# epoch : 15, batch_idx  : 240, triplet_loss : 0.2382084110955281
# epoch : 15, batch_idx  : 260, triplet_loss : 0.23818570187192067
# epoch : 15, batch_idx  : 280, triplet_loss : 0.23806674474825293
# epoch : 15, batch_idx  : 300, triplet_loss : 0.23788516644207786
# epoch : 16, batch_idx  : 20, triplet_loss : 0.23758880599402815
# epoch : 16, batch_idx  : 40, triplet_loss : 0.23767471514708433
# epoch : 16, batch_idx  : 60, triplet_loss : 0.23734989610217666
# epoch : 16, batch_idx  : 80, triplet_loss : 0.2372027628831602
# epoch : 16, batch_idx  : 100, triplet_loss : 0.23698796931417976
# epoch : 16, batch_idx  : 120, triplet_loss : 0.23672750621483787
# epoch : 16, batch_idx  : 140, triplet_loss : 0.23656748772994593
# epoch : 16, batch_idx  : 160, triplet_loss : 0.23634606623086313
# epoch : 16, batch_idx  : 180, triplet_loss : 0.23637567975850887
# epoch : 16, batch_idx  : 200, triplet_loss : 0.23632490975149512
# epoch : 16, batch_idx  : 220, triplet_loss : 0.23585806644394697
# epoch : 16, batch_idx  : 240, triplet_loss : 0.2358369364499593
# epoch : 16, batch_idx  : 260, triplet_loss : 0.23549521204256854
# epoch : 16, batch_idx  : 280, triplet_loss : 0.2354762584982224
# epoch : 16, batch_idx  : 300, triplet_loss : 0.23525172971503835
# epoch : 17, batch_idx  : 20, triplet_loss : 0.23476262329162603
# epoch : 17, batch_idx  : 40, triplet_loss : 0.2347320419280674
# epoch : 17, batch_idx  : 60, triplet_loss : 0.23462000097868993
# epoch : 17, batch_idx  : 80, triplet_loss : 0.23430628342851983
# epoch : 17, batch_idx  : 100, triplet_loss : 0.23408668223473272
# epoch : 17, batch_idx  : 120, triplet_loss : 0.23383558134954913
# epoch : 17, batch_idx  : 140, triplet_loss : 0.23354636475669574
# epoch : 17, batch_idx  : 160, triplet_loss : 0.23336734542913448
# epoch : 17, batch_idx  : 180, triplet_loss : 0.2331229500643994
# epoch : 17, batch_idx  : 200, triplet_loss : 0.23292243219192416
# epoch : 17, batch_idx  : 220, triplet_loss : 0.2328243078055796
# epoch : 17, batch_idx  : 240, triplet_loss : 0.2325988352020959
# epoch : 17, batch_idx  : 260, triplet_loss : 0.23237180265385587
# epoch : 17, batch_idx  : 280, triplet_loss : 0.23208282140888636
# epoch : 17, batch_idx  : 300, triplet_loss : 0.2319110700753928
# epoch : 18, batch_idx  : 20, triplet_loss : 0.2318264295079606
# epoch : 18, batch_idx  : 40, triplet_loss : 0.23170786782452663
# epoch : 18, batch_idx  : 60, triplet_loss : 0.23147464290968114
# epoch : 18, batch_idx  : 80, triplet_loss : 0.23129645018038608
# epoch : 18, batch_idx  : 100, triplet_loss : 0.23102317010964724
# epoch : 18, batch_idx  : 120, triplet_loss : 0.23087367612630433
# epoch : 18, batch_idx  : 140, triplet_loss : 0.2307511894284763
# epoch : 18, batch_idx  : 160, triplet_loss : 0.23054035364525383
# epoch : 18, batch_idx  : 180, triplet_loss : 0.23040584704080128
# epoch : 18, batch_idx  : 200, triplet_loss : 0.23045783679994095
# epoch : 18, batch_idx  : 220, triplet_loss : 0.23028376023082905
# epoch : 18, batch_idx  : 240, triplet_loss : 0.2300971889463483
# epoch : 18, batch_idx  : 260, triplet_loss : 0.22993400213622853
# epoch : 18, batch_idx  : 280, triplet_loss : 0.22984866996087133
# epoch : 18, batch_idx  : 300, triplet_loss : 0.22991404106802005
# epoch : 19, batch_idx  : 20, triplet_loss : 0.2296132268746548
# epoch : 19, batch_idx  : 40, triplet_loss : 0.22947882186290883
# epoch : 19, batch_idx  : 60, triplet_loss : 0.22928208976079126
# epoch : 19, batch_idx  : 80, triplet_loss : 0.22912384191386578
# epoch : 19, batch_idx  : 100, triplet_loss : 0.22883399066430685
# epoch : 19, batch_idx  : 120, triplet_loss : 0.2286693835093976
# epoch : 19, batch_idx  : 140, triplet_loss : 0.2285568804666339
# epoch : 19, batch_idx  : 160, triplet_loss : 0.22853562073371375
# epoch : 19, batch_idx  : 180, triplet_loss : 0.22821180609953157
# epoch : 19, batch_idx  : 200, triplet_loss : 0.22811578020141754
# epoch : 19, batch_idx  : 220, triplet_loss : 0.2280371538922612
# epoch : 19, batch_idx  : 240, triplet_loss : 0.22789135492470253
# epoch : 19, batch_idx  : 260, triplet_loss : 0.22776801587682638
# epoch : 19, batch_idx  : 280, triplet_loss : 0.2276594480199968
# epoch : 19, batch_idx  : 300, triplet_loss : 0.22744736518608016
# epoch : 20, batch_idx  : 20, triplet_loss : 0.22726930650221586
# epoch : 20, batch_idx  : 40, triplet_loss : 0.2270696629778793
# epoch : 20, batch_idx  : 60, triplet_loss : 0.22687635333065054
# epoch : 20, batch_idx  : 80, triplet_loss : 0.22678273874312296
# epoch : 20, batch_idx  : 100, triplet_loss : 0.22640071393152217
# epoch : 20, batch_idx  : 120, triplet_loss : 0.22631207755432894
# epoch : 20, batch_idx  : 140, triplet_loss : 0.2262465751717867
# epoch : 20, batch_idx  : 160, triplet_loss : 0.22599577466267418
# epoch : 20, batch_idx  : 180, triplet_loss : 0.22562687157560588
# epoch : 20, batch_idx  : 200, triplet_loss : 0.2253715133105066
# epoch : 20, batch_idx  : 220, triplet_loss : 0.2252409644350421
# epoch : 20, batch_idx  : 240, triplet_loss : 0.22510911460769925
# epoch : 20, batch_idx  : 260, triplet_loss : 0.22508384525648334
# epoch : 20, batch_idx  : 280, triplet_loss : 0.2248486600880978
# epoch : 20, batch_idx  : 300, triplet_loss : 0.22460319509379065
# epoch : 21, batch_idx  : 20, triplet_loss : 0.22432503575685794
# epoch : 21, batch_idx  : 40, triplet_loss : 0.2241732814321863
# epoch : 21, batch_idx  : 60, triplet_loss : 0.22395960681873725
# epoch : 21, batch_idx  : 80, triplet_loss : 0.22380040266540613
# epoch : 21, batch_idx  : 100, triplet_loss : 0.2236523715749973
# epoch : 21, batch_idx  : 120, triplet_loss : 0.22350275343421316
# epoch : 21, batch_idx  : 140, triplet_loss : 0.22341582850783334
# epoch : 21, batch_idx  : 160, triplet_loss : 0.22338398238802556
# epoch : 21, batch_idx  : 180, triplet_loss : 0.22318675022503548
# epoch : 21, batch_idx  : 200, triplet_loss : 0.2230838927080563
# epoch : 21, batch_idx  : 220, triplet_loss : 0.22294866619788806
# epoch : 21, batch_idx  : 240, triplet_loss : 0.22288450525682516
# epoch : 21, batch_idx  : 260, triplet_loss : 0.2226784311903384
# epoch : 21, batch_idx  : 280, triplet_loss : 0.22245631076856093
# epoch : 21, batch_idx  : 300, triplet_loss : 0.22216603412111224
# epoch : 22, batch_idx  : 20, triplet_loss : 0.22180341557044628
# epoch : 22, batch_idx  : 40, triplet_loss : 0.22158914509609048
# epoch : 22, batch_idx  : 60, triplet_loss : 0.22146692632782117
# epoch : 22, batch_idx  : 80, triplet_loss : 0.22115746253267482
# epoch : 22, batch_idx  : 100, triplet_loss : 0.22118109931728439
# epoch : 22, batch_idx  : 120, triplet_loss : 0.22109380140762816
# epoch : 22, batch_idx  : 140, triplet_loss : 0.22084737376830885
# epoch : 22, batch_idx  : 160, triplet_loss : 0.22070006323823632
# epoch : 22, batch_idx  : 180, triplet_loss : 0.22045027410711618
# epoch : 22, batch_idx  : 200, triplet_loss : 0.2200470365293587
# epoch : 22, batch_idx  : 220, triplet_loss : 0.21994738938773659
# epoch : 22, batch_idx  : 240, triplet_loss : 0.2197833503500734
# epoch : 22, batch_idx  : 260, triplet_loss : 0.21970175145967416
# epoch : 22, batch_idx  : 280, triplet_loss : 0.219482647386425
# epoch : 22, batch_idx  : 300, triplet_loss : 0.21919550811893848
# epoch : 23, batch_idx  : 20, triplet_loss : 0.21899739985643427
# epoch : 23, batch_idx  : 40, triplet_loss : 0.21887714308179412
# epoch : 23, batch_idx  : 60, triplet_loss : 0.2187333202236844
# epoch : 23, batch_idx  : 80, triplet_loss : 0.21854721304367425
# epoch : 23, batch_idx  : 100, triplet_loss : 0.21850921218917455
# epoch : 23, batch_idx  : 120, triplet_loss : 0.21836703630570378
# epoch : 23, batch_idx  : 140, triplet_loss : 0.21831526537960222
# epoch : 23, batch_idx  : 160, triplet_loss : 0.2182459367955585
# epoch : 23, batch_idx  : 180, triplet_loss : 0.218001272410102
# epoch : 23, batch_idx  : 200, triplet_loss : 0.21779571234513434
# epoch : 23, batch_idx  : 220, triplet_loss : 0.217515368147209
# epoch : 23, batch_idx  : 240, triplet_loss : 0.21730055535916235
# epoch : 23, batch_idx  : 260, triplet_loss : 0.2172811847968199
# epoch : 23, batch_idx  : 280, triplet_loss : 0.21712521327887632
# epoch : 23, batch_idx  : 300, triplet_loss : 0.21706257518477443
# epoch : 24, batch_idx  : 20, triplet_loss : 0.21669571764990972
# epoch : 24, batch_idx  : 40, triplet_loss : 0.21653182448624336
# epoch : 24, batch_idx  : 60, triplet_loss : 0.21625195557786805
# epoch : 24, batch_idx  : 80, triplet_loss : 0.21613232498760845
# epoch : 24, batch_idx  : 100, triplet_loss : 0.21596346920824683
# epoch : 24, batch_idx  : 120, triplet_loss : 0.2158206962034412
# epoch : 24, batch_idx  : 140, triplet_loss : 0.21567586477580475
# epoch : 24, batch_idx  : 160, triplet_loss : 0.21555458027053936
# epoch : 24, batch_idx  : 180, triplet_loss : 0.21556108252509695
# epoch : 24, batch_idx  : 200, triplet_loss : 0.2151937131885874
# epoch : 24, batch_idx  : 220, triplet_loss : 0.21517072279144075
# epoch : 24, batch_idx  : 240, triplet_loss : 0.21490834024145009
# epoch : 24, batch_idx  : 260, triplet_loss : 0.21484623365873431
# epoch : 24, batch_idx  : 280, triplet_loss : 0.21459919133233005
# epoch : 24, batch_idx  : 300, triplet_loss : 0.2144186362287623
# epoch : 25, batch_idx  : 20, triplet_loss : 0.21419379408357103
# epoch : 25, batch_idx  : 40, triplet_loss : 0.21401790274464574
# epoch : 25, batch_idx  : 60, triplet_loss : 0.21390370952278365
# epoch : 25, batch_idx  : 80, triplet_loss : 0.21388211664291035
# epoch : 25, batch_idx  : 100, triplet_loss : 0.21365136402708196
# epoch : 25, batch_idx  : 120, triplet_loss : 0.21349869005960648
# epoch : 25, batch_idx  : 140, triplet_loss : 0.21337780985757923
# epoch : 25, batch_idx  : 160, triplet_loss : 0.21316758262658742
# epoch : 25, batch_idx  : 180, triplet_loss : 0.213077308408069
# epoch : 25, batch_idx  : 200, triplet_loss : 0.21290117254014074
# epoch : 25, batch_idx  : 220, triplet_loss : 0.21288072170230213
# epoch : 25, batch_idx  : 240, triplet_loss : 0.2127799574498001
# epoch : 25, batch_idx  : 260, triplet_loss : 0.21275783799319536
# epoch : 25, batch_idx  : 280, triplet_loss : 0.21247558061149402
# epoch : 25, batch_idx  : 300, triplet_loss : 0.2122720337790838
# epoch : 26, batch_idx  : 20, triplet_loss : 0.21197009918780027
# epoch : 26, batch_idx  : 40, triplet_loss : 0.21191364864363021
# epoch : 26, batch_idx  : 60, triplet_loss : 0.2117764462218096
# epoch : 26, batch_idx  : 80, triplet_loss : 0.21180692402032594
# epoch : 26, batch_idx  : 100, triplet_loss : 0.21164570661905097
# epoch : 26, batch_idx  : 120, triplet_loss : 0.21139758072959852
# epoch : 26, batch_idx  : 140, triplet_loss : 0.21135453201251744
# epoch : 26, batch_idx  : 160, triplet_loss : 0.2112374823533737
# epoch : 26, batch_idx  : 180, triplet_loss : 0.21109857806872293
# epoch : 26, batch_idx  : 200, triplet_loss : 0.2109782779441219
# epoch : 26, batch_idx  : 220, triplet_loss : 0.2107885488155134
# epoch : 26, batch_idx  : 240, triplet_loss : 0.2107043549409585
# epoch : 26, batch_idx  : 260, triplet_loss : 0.2105804999026771
# epoch : 26, batch_idx  : 280, triplet_loss : 0.21041596199260654
# epoch : 26, batch_idx  : 300, triplet_loss : 0.21009445549712263
# epoch : 27, batch_idx  : 20, triplet_loss : 0.20982528790605393
# epoch : 27, batch_idx  : 40, triplet_loss : 0.2096245659619993
# epoch : 27, batch_idx  : 60, triplet_loss : 0.2094814973747106
# epoch : 27, batch_idx  : 80, triplet_loss : 0.20932829409109988
# epoch : 27, batch_idx  : 100, triplet_loss : 0.20927280450405003
# epoch : 27, batch_idx  : 120, triplet_loss : 0.20893818777908432
# epoch : 27, batch_idx  : 140, triplet_loss : 0.20876287463293897
# epoch : 27, batch_idx  : 160, triplet_loss : 0.2085703671554653
# epoch : 27, batch_idx  : 180, triplet_loss : 0.20830115645466507
# epoch : 27, batch_idx  : 200, triplet_loss : 0.2081334219764957
# epoch : 27, batch_idx  : 220, triplet_loss : 0.20801730542700103
# epoch : 27, batch_idx  : 240, triplet_loss : 0.20799305572916107
# epoch : 27, batch_idx  : 260, triplet_loss : 0.20786478268716876
# epoch : 27, batch_idx  : 280, triplet_loss : 0.20764932353851226
# epoch : 27, batch_idx  : 300, triplet_loss : 0.20732222355733307
# epoch : 28, batch_idx  : 20, triplet_loss : 0.2067272711778139
# epoch : 28, batch_idx  : 40, triplet_loss : 0.2065722743928817
# epoch : 28, batch_idx  : 60, triplet_loss : 0.20652231482493733
# epoch : 28, batch_idx  : 80, triplet_loss : 0.2062955677650376
# epoch : 28, batch_idx  : 100, triplet_loss : 0.20608464641443966
# epoch : 28, batch_idx  : 120, triplet_loss : 0.20589240132913061
# epoch : 28, batch_idx  : 140, triplet_loss : 0.20573168650367926
# epoch : 28, batch_idx  : 160, triplet_loss : 0.20568094336226256
# epoch : 28, batch_idx  : 180, triplet_loss : 0.2056247402224588
# epoch : 28, batch_idx  : 200, triplet_loss : 0.20558916421205942
# epoch : 28, batch_idx  : 220, triplet_loss : 0.20541995750221656
# epoch : 28, batch_idx  : 240, triplet_loss : 0.20532322725386076
# epoch : 28, batch_idx  : 260, triplet_loss : 0.20527571467066502
# epoch : 28, batch_idx  : 280, triplet_loss : 0.20516013997623048
# epoch : 28, batch_idx  : 300, triplet_loss : 0.2050225069410636
# epoch : 29, batch_idx  : 20, triplet_loss : 0.2048636535583614
# epoch : 29, batch_idx  : 40, triplet_loss : 0.20471020477370927
# epoch : 29, batch_idx  : 60, triplet_loss : 0.20451805193525396
# epoch : 29, batch_idx  : 80, triplet_loss : 0.20437437003632294
# epoch : 29, batch_idx  : 100, triplet_loss : 0.20421795036384385
# epoch : 29, batch_idx  : 120, triplet_loss : 0.20407408287895454
# epoch : 29, batch_idx  : 140, triplet_loss : 0.2040716195842621
# epoch : 29, batch_idx  : 160, triplet_loss : 0.2039940524727727
# epoch : 29, batch_idx  : 180, triplet_loss : 0.20378717289451534
# epoch : 29, batch_idx  : 200, triplet_loss : 0.2037297511242944
# epoch : 29, batch_idx  : 220, triplet_loss : 0.20352650155230737
# epoch : 29, batch_idx  : 240, triplet_loss : 0.20339079437962926
# epoch : 29, batch_idx  : 260, triplet_loss : 0.20321110831109288
# epoch : 29, batch_idx  : 280, triplet_loss : 0.20304510316757826
# epoch : 29, batch_idx  : 300, triplet_loss : 0.20302704483685666
# epoch : 30, batch_idx  : 20, triplet_loss : 0.2028028977481052
# epoch : 30, batch_idx  : 40, triplet_loss : 0.2027200639370745
# epoch : 30, batch_idx  : 60, triplet_loss : 0.20245691904908758
# epoch : 30, batch_idx  : 80, triplet_loss : 0.20230212988175664
# epoch : 30, batch_idx  : 100, triplet_loss : 0.20209591637832405
# epoch : 30, batch_idx  : 120, triplet_loss : 0.20206927773231806
# epoch : 30, batch_idx  : 140, triplet_loss : 0.2019699780156879
# epoch : 30, batch_idx  : 160, triplet_loss : 0.20184934043912894
# epoch : 30, batch_idx  : 180, triplet_loss : 0.2017611889646843
# epoch : 30, batch_idx  : 200, triplet_loss : 0.2016203008602196
# epoch : 30, batch_idx  : 220, triplet_loss : 0.2014847371760845
# epoch : 30, batch_idx  : 240, triplet_loss : 0.20144412125869637
# epoch : 30, batch_idx  : 260, triplet_loss : 0.20139575007194305
# epoch : 30, batch_idx  : 280, triplet_loss : 0.20126259752726164
# epoch : 30, batch_idx  : 300, triplet_loss : 0.20117188821958792
# epoch : 31, batch_idx  : 20, triplet_loss : 0.20076187292103398
# epoch : 31, batch_idx  : 40, triplet_loss : 0.20067312858293734
# epoch : 31, batch_idx  : 60, triplet_loss : 0.2005278817271018
# epoch : 31, batch_idx  : 80, triplet_loss : 0.20042897608895965
# epoch : 31, batch_idx  : 100, triplet_loss : 0.20025948905435745
# epoch : 31, batch_idx  : 120, triplet_loss : 0.20020001283882233
# epoch : 31, batch_idx  : 140, triplet_loss : 0.2000854199596598
# epoch : 31, batch_idx  : 160, triplet_loss : 0.19991408063041374
# epoch : 31, batch_idx  : 180, triplet_loss : 0.1997487246960146
# epoch : 31, batch_idx  : 200, triplet_loss : 0.19958426156233589
# epoch : 31, batch_idx  : 220, triplet_loss : 0.19938609972184534
# epoch : 31, batch_idx  : 240, triplet_loss : 0.1992810655357246
# epoch : 31, batch_idx  : 260, triplet_loss : 0.19909797250896527
# epoch : 31, batch_idx  : 280, triplet_loss : 0.1989782617024285
# epoch : 31, batch_idx  : 300, triplet_loss : 0.19880341430713006
# epoch : 32, batch_idx  : 20, triplet_loss : 0.19853428980541485
# epoch : 32, batch_idx  : 40, triplet_loss : 0.1984252022206931
# epoch : 32, batch_idx  : 60, triplet_loss : 0.19836294868895935
# epoch : 32, batch_idx  : 80, triplet_loss : 0.19827955112968995
# epoch : 32, batch_idx  : 100, triplet_loss : 0.1981783460773192
# epoch : 32, batch_idx  : 120, triplet_loss : 0.1980269808798064
# epoch : 32, batch_idx  : 140, triplet_loss : 0.19781160471173542
# epoch : 32, batch_idx  : 160, triplet_loss : 0.1976410534857933
# epoch : 32, batch_idx  : 180, triplet_loss : 0.19750739777090495
# epoch : 32, batch_idx  : 200, triplet_loss : 0.19734620584756737
# epoch : 32, batch_idx  : 220, triplet_loss : 0.197247351056959
# epoch : 32, batch_idx  : 240, triplet_loss : 0.19710042921502013
# epoch : 32, batch_idx  : 260, triplet_loss : 0.19699694101627058
# epoch : 32, batch_idx  : 280, triplet_loss : 0.19675590958158096
# epoch : 32, batch_idx  : 300, triplet_loss : 0.1964977288092953
# epoch : 33, batch_idx  : 20, triplet_loss : 0.19636244427075128
# epoch : 33, batch_idx  : 40, triplet_loss : 0.1962649959687326
# epoch : 33, batch_idx  : 60, triplet_loss : 0.19622095156102518
# epoch : 33, batch_idx  : 80, triplet_loss : 0.1961563383980431
# epoch : 33, batch_idx  : 100, triplet_loss : 0.1961347134838161
# epoch : 33, batch_idx  : 120, triplet_loss : 0.19596217815047923
# epoch : 33, batch_idx  : 140, triplet_loss : 0.19582025402161798
# epoch : 33, batch_idx  : 160, triplet_loss : 0.19567185670355478
# epoch : 33, batch_idx  : 180, triplet_loss : 0.19562773954469181
# epoch : 33, batch_idx  : 200, triplet_loss : 0.1955464241191608
# epoch : 33, batch_idx  : 220, triplet_loss : 0.19539489073788502
# epoch : 33, batch_idx  : 240, triplet_loss : 0.19524411731909483
# epoch : 33, batch_idx  : 260, triplet_loss : 0.195013823638716
# epoch : 33, batch_idx  : 280, triplet_loss : 0.19486604392231716
# epoch : 33, batch_idx  : 300, triplet_loss : 0.19463267416519373
# epoch : 34, batch_idx  : 20, triplet_loss : 0.19439493237148436
# epoch : 34, batch_idx  : 40, triplet_loss : 0.194250227605895
# epoch : 34, batch_idx  : 60, triplet_loss : 0.19418593211092738
# epoch : 34, batch_idx  : 80, triplet_loss : 0.19393075993593667
# epoch : 34, batch_idx  : 100, triplet_loss : 0.19379601998907456
# epoch : 34, batch_idx  : 120, triplet_loss : 0.1936338631695174
# epoch : 34, batch_idx  : 140, triplet_loss : 0.19355042726063207
# epoch : 34, batch_idx  : 160, triplet_loss : 0.19341742908249507
# epoch : 34, batch_idx  : 180, triplet_loss : 0.19328487485419368
# epoch : 34, batch_idx  : 200, triplet_loss : 0.19319834395554
# epoch : 34, batch_idx  : 220, triplet_loss : 0.19312770758636108
# epoch : 34, batch_idx  : 240, triplet_loss : 0.19292628001553067
# epoch : 34, batch_idx  : 260, triplet_loss : 0.1928151185114488
# epoch : 34, batch_idx  : 280, triplet_loss : 0.19266507447859313
# epoch : 34, batch_idx  : 300, triplet_loss : 0.19267035732560767
# epoch : 35, batch_idx  : 20, triplet_loss : 0.19244095281980395
# epoch : 35, batch_idx  : 40, triplet_loss : 0.19230199107102758
# epoch : 35, batch_idx  : 60, triplet_loss : 0.19220736605011493
# epoch : 35, batch_idx  : 80, triplet_loss : 0.1921247951292688
# epoch : 35, batch_idx  : 100, triplet_loss : 0.19198679911381988
# epoch : 35, batch_idx  : 120, triplet_loss : 0.19187981652565472
# epoch : 35, batch_idx  : 140, triplet_loss : 0.19167321189995692
# epoch : 35, batch_idx  : 160, triplet_loss : 0.19151652181600734
# epoch : 35, batch_idx  : 180, triplet_loss : 0.19137830467630057
# epoch : 35, batch_idx  : 200, triplet_loss : 0.19129037549338895
# epoch : 35, batch_idx  : 220, triplet_loss : 0.1912189005274233
# epoch : 35, batch_idx  : 240, triplet_loss : 0.19107572817014848
# epoch : 35, batch_idx  : 260, triplet_loss : 0.191058490886581
# epoch : 35, batch_idx  : 280, triplet_loss : 0.19093515572367264
# epoch : 35, batch_idx  : 300, triplet_loss : 0.19085071039056242
# epoch : 36, batch_idx  : 20, triplet_loss : 0.19072270494949475
# epoch : 36, batch_idx  : 40, triplet_loss : 0.19053787197137836
# epoch : 36, batch_idx  : 60, triplet_loss : 0.19043434848619673
# epoch : 36, batch_idx  : 80, triplet_loss : 0.1903689384460449
# epoch : 36, batch_idx  : 100, triplet_loss : 0.19016264234128516
# epoch : 36, batch_idx  : 120, triplet_loss : 0.1900278348265383
# epoch : 36, batch_idx  : 140, triplet_loss : 0.18996162936905162
# epoch : 36, batch_idx  : 160, triplet_loss : 0.1897804498334561
# epoch : 36, batch_idx  : 180, triplet_loss : 0.1895465364832955
# epoch : 36, batch_idx  : 200, triplet_loss : 0.18935404880727597
# epoch : 36, batch_idx  : 220, triplet_loss : 0.1892253323620157
# epoch : 36, batch_idx  : 240, triplet_loss : 0.18907336540013592
# epoch : 36, batch_idx  : 260, triplet_loss : 0.18897825955983832
# epoch : 36, batch_idx  : 280, triplet_loss : 0.1888003171776511
# epoch : 36, batch_idx  : 300, triplet_loss : 0.18864002665894034
# epoch : 37, batch_idx  : 20, triplet_loss : 0.18854478959754956
# epoch : 37, batch_idx  : 40, triplet_loss : 0.18845434177953513
# epoch : 37, batch_idx  : 60, triplet_loss : 0.18831405951017507
# epoch : 37, batch_idx  : 80, triplet_loss : 0.1882394598517543
# epoch : 37, batch_idx  : 100, triplet_loss : 0.18811821149461394
# epoch : 37, batch_idx  : 120, triplet_loss : 0.1879749998129128
# epoch : 37, batch_idx  : 140, triplet_loss : 0.1878334121625433
# epoch : 37, batch_idx  : 160, triplet_loss : 0.18770357302265667
# epoch : 37, batch_idx  : 180, triplet_loss : 0.1875963759645586
# epoch : 37, batch_idx  : 200, triplet_loss : 0.18734754281950156
# epoch : 37, batch_idx  : 220, triplet_loss : 0.18717822010870147
# epoch : 37, batch_idx  : 240, triplet_loss : 0.18702395928681062
# epoch : 37, batch_idx  : 260, triplet_loss : 0.18694370024653234
# epoch : 37, batch_idx  : 280, triplet_loss : 0.18674221898850418
# epoch : 37, batch_idx  : 300, triplet_loss : 0.18659657385187448
# epoch : 38, batch_idx  : 20, triplet_loss : 0.1863896071083085
# epoch : 38, batch_idx  : 40, triplet_loss : 0.18623455054357935
# epoch : 38, batch_idx  : 60, triplet_loss : 0.18615156109703002
# epoch : 38, batch_idx  : 80, triplet_loss : 0.18599617554416448
# epoch : 38, batch_idx  : 100, triplet_loss : 0.18586639037311975
# epoch : 38, batch_idx  : 120, triplet_loss : 0.1858202624454999
# epoch : 38, batch_idx  : 140, triplet_loss : 0.18567012728573837
# epoch : 38, batch_idx  : 160, triplet_loss : 0.18552750224467987
# epoch : 38, batch_idx  : 180, triplet_loss : 0.18545670053753796
# epoch : 38, batch_idx  : 200, triplet_loss : 0.1852933771396758
# epoch : 38, batch_idx  : 220, triplet_loss : 0.18520777794345264
# epoch : 38, batch_idx  : 240, triplet_loss : 0.1850550999779401
# epoch : 38, batch_idx  : 260, triplet_loss : 0.18495786584407167
# epoch : 38, batch_idx  : 280, triplet_loss : 0.18480423830274495
# epoch : 38, batch_idx  : 300, triplet_loss : 0.18468762813736664
# epoch : 39, batch_idx  : 20, triplet_loss : 0.18439521202444786
# epoch : 39, batch_idx  : 40, triplet_loss : 0.1843325385819753
# epoch : 39, batch_idx  : 60, triplet_loss : 0.18417726905231424
# epoch : 39, batch_idx  : 80, triplet_loss : 0.18408682890411052
# epoch : 39, batch_idx  : 100, triplet_loss : 0.18401430980381217
# epoch : 39, batch_idx  : 120, triplet_loss : 0.18391529940417545
# epoch : 39, batch_idx  : 140, triplet_loss : 0.18385462773869227
# epoch : 39, batch_idx  : 160, triplet_loss : 0.18382527528776116
# epoch : 39, batch_idx  : 180, triplet_loss : 0.18372855241524874
# epoch : 39, batch_idx  : 200, triplet_loss : 0.18366958364584537
# epoch : 39, batch_idx  : 220, triplet_loss : 0.18346506093282158
# epoch : 39, batch_idx  : 240, triplet_loss : 0.1833455531541003
# epoch : 39, batch_idx  : 260, triplet_loss : 0.18330419026872205
# epoch : 39, batch_idx  : 280, triplet_loss : 0.1831900906613241
# epoch : 39, batch_idx  : 300, triplet_loss : 0.18302426428360474
# epoch : 40, batch_idx  : 20, triplet_loss : 0.1828394907048241
# epoch : 40, batch_idx  : 40, triplet_loss : 0.18274300571765495
# epoch : 40, batch_idx  : 60, triplet_loss : 0.18264084362292307
# epoch : 40, batch_idx  : 80, triplet_loss : 0.1824733386518042
# epoch : 40, batch_idx  : 100, triplet_loss : 0.18234328124706012
# epoch : 40, batch_idx  : 120, triplet_loss : 0.18212159518168633
# epoch : 40, batch_idx  : 140, triplet_loss : 0.18199067675037728
# epoch : 40, batch_idx  : 160, triplet_loss : 0.18183088445989565
# epoch : 40, batch_idx  : 180, triplet_loss : 0.18179776124055638
# epoch : 40, batch_idx  : 200, triplet_loss : 0.1817261037029879
# epoch : 40, batch_idx  : 220, triplet_loss : 0.1816270892006925
# epoch : 40, batch_idx  : 240, triplet_loss : 0.18152218672709766
# epoch : 40, batch_idx  : 260, triplet_loss : 0.18141660345073946
# epoch : 40, batch_idx  : 280, triplet_loss : 0.18131817347089335
# epoch : 40, batch_idx  : 300, triplet_loss : 0.18119870141193753
# epoch : 41, batch_idx  : 20, triplet_loss : 0.18097466271068754
# epoch : 41, batch_idx  : 40, triplet_loss : 0.18082661082981816
# epoch : 41, batch_idx  : 60, triplet_loss : 0.18064824586721936
# epoch : 41, batch_idx  : 80, triplet_loss : 0.18048755668020303
# epoch : 41, batch_idx  : 100, triplet_loss : 0.18035976896625952
# epoch : 41, batch_idx  : 120, triplet_loss : 0.18016315412181944
# epoch : 41, batch_idx  : 140, triplet_loss : 0.1799634333074528
# epoch : 41, batch_idx  : 160, triplet_loss : 0.17984297535499028
# epoch : 41, batch_idx  : 180, triplet_loss : 0.17971455349587975
# epoch : 41, batch_idx  : 200, triplet_loss : 0.17958329138518747
# epoch : 41, batch_idx  : 220, triplet_loss : 0.1794561488544636
# epoch : 41, batch_idx  : 240, triplet_loss : 0.1793781093159478
# epoch : 41, batch_idx  : 260, triplet_loss : 0.17922066834247924
# epoch : 41, batch_idx  : 280, triplet_loss : 0.17911062841177983
# epoch : 41, batch_idx  : 300, triplet_loss : 0.17916851596995143
# epoch : 42, batch_idx  : 20, triplet_loss : 0.17893718521134191
# epoch : 42, batch_idx  : 40, triplet_loss : 0.17886914846866306
# epoch : 42, batch_idx  : 60, triplet_loss : 0.17874141684504524
# epoch : 42, batch_idx  : 80, triplet_loss : 0.17868784259353696
# epoch : 42, batch_idx  : 100, triplet_loss : 0.17867309096812375
# epoch : 42, batch_idx  : 120, triplet_loss : 0.17854148235925824
# epoch : 42, batch_idx  : 140, triplet_loss : 0.17840087688580056
# epoch : 42, batch_idx  : 160, triplet_loss : 0.17835765488764455
# epoch : 42, batch_idx  : 180, triplet_loss : 0.1782661978977675
# epoch : 42, batch_idx  : 200, triplet_loss : 0.17815526724373648
# epoch : 42, batch_idx  : 220, triplet_loss : 0.17815302994255874
# epoch : 42, batch_idx  : 240, triplet_loss : 0.1780498331983159
# epoch : 42, batch_idx  : 260, triplet_loss : 0.17798626431635087
# epoch : 42, batch_idx  : 280, triplet_loss : 0.17788600343352073
# epoch : 42, batch_idx  : 300, triplet_loss : 0.17783727258856985
# epoch : 43, batch_idx  : 20, triplet_loss : 0.17760525368567817
# epoch : 43, batch_idx  : 40, triplet_loss : 0.17748881704824182
# epoch : 43, batch_idx  : 60, triplet_loss : 0.17740099506265494
# epoch : 43, batch_idx  : 80, triplet_loss : 0.17734390992962243
# epoch : 43, batch_idx  : 100, triplet_loss : 0.17721434360824506
# epoch : 43, batch_idx  : 120, triplet_loss : 0.1771076811186448
# epoch : 43, batch_idx  : 140, triplet_loss : 0.17702651325645208
# epoch : 43, batch_idx  : 160, triplet_loss : 0.1769802795610883
# epoch : 43, batch_idx  : 180, triplet_loss : 0.17685760792445815
# epoch : 43, batch_idx  : 200, triplet_loss : 0.17668206930826033
# epoch : 43, batch_idx  : 220, triplet_loss : 0.17652723499487782
# epoch : 43, batch_idx  : 240, triplet_loss : 0.17647815510638198
# epoch : 43, batch_idx  : 260, triplet_loss : 0.17635675026265582
# epoch : 43, batch_idx  : 280, triplet_loss : 0.17628792346579014
# epoch : 43, batch_idx  : 300, triplet_loss : 0.1762008550680436
# epoch : 44, batch_idx  : 20, triplet_loss : 0.17599375789251823
# epoch : 44, batch_idx  : 40, triplet_loss : 0.1759426147917816
# epoch : 44, batch_idx  : 60, triplet_loss : 0.17585670416281426
# epoch : 44, batch_idx  : 80, triplet_loss : 0.17572423094098
# epoch : 44, batch_idx  : 100, triplet_loss : 0.1756547894908358
# epoch : 44, batch_idx  : 120, triplet_loss : 0.17549086650962456
# epoch : 44, batch_idx  : 140, triplet_loss : 0.17534633125383037
# epoch : 44, batch_idx  : 160, triplet_loss : 0.1752311214714029
# epoch : 44, batch_idx  : 180, triplet_loss : 0.17511075711138735
# epoch : 44, batch_idx  : 200, triplet_loss : 0.1750046504407498
# epoch : 44, batch_idx  : 220, triplet_loss : 0.17490647153598066
# epoch : 44, batch_idx  : 240, triplet_loss : 0.17479114069503274
# epoch : 44, batch_idx  : 260, triplet_loss : 0.1746920587239198
# epoch : 44, batch_idx  : 280, triplet_loss : 0.17463990847544525
# epoch : 44, batch_idx  : 300, triplet_loss : 0.17453128661731573
# epoch : 45, batch_idx  : 20, triplet_loss : 0.17431433641015914
# epoch : 45, batch_idx  : 40, triplet_loss : 0.17420998794960493
# epoch : 45, batch_idx  : 60, triplet_loss : 0.17406035351955684
# epoch : 45, batch_idx  : 80, triplet_loss : 0.17391885211399627
# epoch : 45, batch_idx  : 100, triplet_loss : 0.17377838730397424
# epoch : 45, batch_idx  : 120, triplet_loss : 0.1736450312223512
# epoch : 45, batch_idx  : 140, triplet_loss : 0.17352352025659906
# epoch : 45, batch_idx  : 160, triplet_loss : 0.17331527473189817
# epoch : 45, batch_idx  : 180, triplet_loss : 0.17318148887779683
# epoch : 45, batch_idx  : 200, triplet_loss : 0.1730651823651324
# epoch : 45, batch_idx  : 220, triplet_loss : 0.17295104705259848
# epoch : 45, batch_idx  : 240, triplet_loss : 0.17291923009041132
# epoch : 45, batch_idx  : 260, triplet_loss : 0.1728486782146307
# epoch : 45, batch_idx  : 280, triplet_loss : 0.17283185579652516
# epoch : 45, batch_idx  : 300, triplet_loss : 0.17271592208794104
# epoch : 46, batch_idx  : 20, triplet_loss : 0.17247898639628848
# epoch : 46, batch_idx  : 40, triplet_loss : 0.17240392180982028
# epoch : 46, batch_idx  : 60, triplet_loss : 0.17226826296268516
# epoch : 46, batch_idx  : 80, triplet_loss : 0.1721425513043461
# epoch : 46, batch_idx  : 100, triplet_loss : 0.17196716746541388
# epoch : 46, batch_idx  : 120, triplet_loss : 0.17186591550733393
# epoch : 46, batch_idx  : 140, triplet_loss : 0.17170571436569795
# epoch : 46, batch_idx  : 160, triplet_loss : 0.17156997378743377
# epoch : 46, batch_idx  : 180, triplet_loss : 0.1714211717039092
# epoch : 46, batch_idx  : 200, triplet_loss : 0.17131786607523833
# epoch : 46, batch_idx  : 220, triplet_loss : 0.17118758579650675
# epoch : 46, batch_idx  : 240, triplet_loss : 0.17110575467682956
# epoch : 46, batch_idx  : 260, triplet_loss : 0.17094173491487533
# epoch : 46, batch_idx  : 280, triplet_loss : 0.17087152773030545
# epoch : 46, batch_idx  : 300, triplet_loss : 0.17070253936769034
# epoch : 47, batch_idx  : 20, triplet_loss : 0.17064543626383294
# epoch : 47, batch_idx  : 40, triplet_loss : 0.17046521980441562
# epoch : 47, batch_idx  : 60, triplet_loss : 0.17034847878522497
# epoch : 47, batch_idx  : 80, triplet_loss : 0.17026090771070315
# epoch : 47, batch_idx  : 100, triplet_loss : 0.17020020769268837
# epoch : 47, batch_idx  : 120, triplet_loss : 0.1701014082791448
# epoch : 47, batch_idx  : 140, triplet_loss : 0.1701105588948185
# epoch : 47, batch_idx  : 160, triplet_loss : 0.17001779392842065
# epoch : 47, batch_idx  : 180, triplet_loss : 0.1699707640969727
# epoch : 47, batch_idx  : 200, triplet_loss : 0.1698819511512821
# epoch : 47, batch_idx  : 220, triplet_loss : 0.16981668612736392
# epoch : 47, batch_idx  : 240, triplet_loss : 0.1697158768104469
# epoch : 47, batch_idx  : 260, triplet_loss : 0.16965151702554448
# epoch : 47, batch_idx  : 280, triplet_loss : 0.1695644992204714
# epoch : 47, batch_idx  : 300, triplet_loss : 0.16948444862667011
# epoch : 48, batch_idx  : 20, triplet_loss : 0.1692683059836464
# epoch : 48, batch_idx  : 40, triplet_loss : 0.16915463955876592
# epoch : 48, batch_idx  : 60, triplet_loss : 0.16907726036421505
# epoch : 48, batch_idx  : 80, triplet_loss : 0.16902117537368858
# epoch : 48, batch_idx  : 100, triplet_loss : 0.16889976694122236
# epoch : 48, batch_idx  : 120, triplet_loss : 0.16880109207186683
# epoch : 48, batch_idx  : 140, triplet_loss : 0.16871034645814048
# epoch : 48, batch_idx  : 160, triplet_loss : 0.16854899472642662
# epoch : 48, batch_idx  : 180, triplet_loss : 0.1684819836708504
# epoch : 48, batch_idx  : 200, triplet_loss : 0.16836438824684316
# epoch : 48, batch_idx  : 220, triplet_loss : 0.16825360268547343
# epoch : 48, batch_idx  : 240, triplet_loss : 0.16810260880669162
# epoch : 48, batch_idx  : 260, triplet_loss : 0.16801506377596728
# epoch : 48, batch_idx  : 280, triplet_loss : 0.16793403609551522
# epoch : 48, batch_idx  : 300, triplet_loss : 0.16785509161835788
# epoch : 49, batch_idx  : 20, triplet_loss : 0.1676861250937128
# epoch : 49, batch_idx  : 40, triplet_loss : 0.16758442660592632
# epoch : 49, batch_idx  : 60, triplet_loss : 0.16750969857627646
# epoch : 49, batch_idx  : 80, triplet_loss : 0.16749770515639603
# epoch : 49, batch_idx  : 100, triplet_loss : 0.16739651216614382
# epoch : 49, batch_idx  : 120, triplet_loss : 0.16727073996646066
# epoch : 49, batch_idx  : 140, triplet_loss : 0.16722477086902302
# epoch : 49, batch_idx  : 160, triplet_loss : 0.1671683758941963
# epoch : 49, batch_idx  : 180, triplet_loss : 0.16706594956792634
# epoch : 49, batch_idx  : 200, triplet_loss : 0.16700901227806686
# epoch : 49, batch_idx  : 220, triplet_loss : 0.16690402228258464
# epoch : 49, batch_idx  : 240, triplet_loss : 0.16683730944860475
# ...
# epoch : 83, batch_idx  : 160, triplet_loss : 0.13056447347307515
# epoch : 83, batch_idx  : 180, triplet_loss : 0.13051899915385554
# epoch : 83, batch_idx  : 200, triplet_loss : 0.13044799055658898
# epoch : 83, batch_idx  : 220, triplet_loss : 0.13038819958400052
# epoch : 83, batch_idx  : 240, triplet_loss : 0.13034763599851124
# epoch : 83, batch_idx  : 260, triplet_loss : 0.1302882470837282
# epoch : 83, batch_idx  : 280, triplet_loss : 0.13021663480852955
# epoch : 83, batch_idx  : 300, triplet_loss : 0.1301523208549206
# epoch : 84, batch_idx  : 20, triplet_loss : 0.130032550193132
# epoch : 84, batch_idx  : 40, triplet_loss : 0.1299640401556485
# epoch : 84, batch_idx  : 60, triplet_loss : 0.12989091760382987
# epoch : 84, batch_idx  : 80, triplet_loss : 0.12985801481007042
# epoch : 84, batch_idx  : 100, triplet_loss : 0.1298039374447357
# epoch : 84, batch_idx  : 120, triplet_loss : 0.1297260723423498
# epoch : 84, batch_idx  : 140, triplet_loss : 0.12970581727552166
# epoch : 84, batch_idx  : 160, triplet_loss : 0.12964608449433146
# epoch : 84, batch_idx  : 180, triplet_loss : 0.129628792841104
# epoch : 84, batch_idx  : 200, triplet_loss : 0.1295961839250182
# epoch : 84, batch_idx  : 220, triplet_loss : 0.12955099008995621
# epoch : 84, batch_idx  : 240, triplet_loss : 0.129500655670745
# epoch : 84, batch_idx  : 260, triplet_loss : 0.12945283125075832
# epoch : 84, batch_idx  : 280, triplet_loss : 0.1294546062509319
# epoch : 84, batch_idx  : 300, triplet_loss : 0.12941091823967543
# epoch : 85, batch_idx  : 20, triplet_loss : 0.1293414895461145
# epoch : 85, batch_idx  : 40, triplet_loss : 0.12930087393718262
# epoch : 85, batch_idx  : 60, triplet_loss : 0.1292117577834217
# epoch : 85, batch_idx  : 80, triplet_loss : 0.12919005404392875
# epoch : 85, batch_idx  : 100, triplet_loss : 0.1291238781715364
# epoch : 85, batch_idx  : 120, triplet_loss : 0.1290495351197572
# epoch : 85, batch_idx  : 140, triplet_loss : 0.1290044732296588
# epoch : 85, batch_idx  : 160, triplet_loss : 0.1289888088882784
# epoch : 85, batch_idx  : 180, triplet_loss : 0.12892910620302117
# epoch : 85, batch_idx  : 200, triplet_loss : 0.12888927758127913
# epoch : 85, batch_idx  : 220, triplet_loss : 0.1288580254148309
# epoch : 85, batch_idx  : 240, triplet_loss : 0.1288211139697847
# epoch : 85, batch_idx  : 260, triplet_loss : 0.12875727070938842
# epoch : 85, batch_idx  : 280, triplet_loss : 0.1287236326756332
# epoch : 85, batch_idx  : 300, triplet_loss : 0.1286704421743432
# epoch : 86, batch_idx  : 20, triplet_loss : 0.12863209567171463
# epoch : 86, batch_idx  : 40, triplet_loss : 0.12858038886811293
# epoch : 86, batch_idx  : 60, triplet_loss : 0.12852447220011953
# epoch : 86, batch_idx  : 80, triplet_loss : 0.1284819550590804
# epoch : 86, batch_idx  : 100, triplet_loss : 0.1284377950371642
# epoch : 86, batch_idx  : 120, triplet_loss : 0.12838427149095843
# epoch : 86, batch_idx  : 140, triplet_loss : 0.12832224237521417
# epoch : 86, batch_idx  : 160, triplet_loss : 0.1282807752591524
# epoch : 86, batch_idx  : 180, triplet_loss : 0.1282297946237259
# epoch : 86, batch_idx  : 200, triplet_loss : 0.12821773299397934
# epoch : 86, batch_idx  : 220, triplet_loss : 0.12816580253746446
# epoch : 86, batch_idx  : 240, triplet_loss : 0.12813807191335078
# epoch : 86, batch_idx  : 260, triplet_loss : 0.12805381141822972
# epoch : 86, batch_idx  : 280, triplet_loss : 0.12798998779771703
# epoch : 86, batch_idx  : 300, triplet_loss : 0.12791919598996782
# epoch : 87, batch_idx  : 20, triplet_loss : 0.12781453240767598
# epoch : 87, batch_idx  : 40, triplet_loss : 0.12777727996794522
# epoch : 87, batch_idx  : 60, triplet_loss : 0.1277205267639234
# epoch : 87, batch_idx  : 80, triplet_loss : 0.12768837028582813
# epoch : 87, batch_idx  : 100, triplet_loss : 0.12762430565458682
# epoch : 87, batch_idx  : 120, triplet_loss : 0.12757284681713352
# epoch : 87, batch_idx  : 140, triplet_loss : 0.12753081101826635
# epoch : 87, batch_idx  : 160, triplet_loss : 0.12745116226945305
# epoch : 87, batch_idx  : 180, triplet_loss : 0.12741739781814349
# epoch : 87, batch_idx  : 200, triplet_loss : 0.12734211628843115
# epoch : 87, batch_idx  : 220, triplet_loss : 0.12727287123178951
# epoch : 87, batch_idx  : 240, triplet_loss : 0.1272305499171176
# epoch : 87, batch_idx  : 260, triplet_loss : 0.12715973718209836
# epoch : 87, batch_idx  : 280, triplet_loss : 0.12711470225759294
# epoch : 87, batch_idx  : 300, triplet_loss : 0.12709708910592846
# epoch : 88, batch_idx  : 20, triplet_loss : 0.12701308941516085
# epoch : 88, batch_idx  : 40, triplet_loss : 0.12697857208338625
# epoch : 88, batch_idx  : 60, triplet_loss : 0.12691746525299905
# epoch : 88, batch_idx  : 80, triplet_loss : 0.12684893522814722
# epoch : 88, batch_idx  : 100, triplet_loss : 0.1268335537024462
# epoch : 88, batch_idx  : 120, triplet_loss : 0.1267824548678549
# epoch : 88, batch_idx  : 140, triplet_loss : 0.12673326193507298
# epoch : 88, batch_idx  : 160, triplet_loss : 0.1267082859006949
# epoch : 88, batch_idx  : 180, triplet_loss : 0.1266381288718728
# epoch : 88, batch_idx  : 200, triplet_loss : 0.12656117573375653
# epoch : 88, batch_idx  : 220, triplet_loss : 0.12650035608629262
# epoch : 88, batch_idx  : 240, triplet_loss : 0.12646917423925508
# epoch : 88, batch_idx  : 260, triplet_loss : 0.12644216517098075
# epoch : 88, batch_idx  : 280, triplet_loss : 0.12639878239412308
# epoch : 88, batch_idx  : 300, triplet_loss : 0.12636757201472096
# epoch : 89, batch_idx  : 20, triplet_loss : 0.12626941016648996
# epoch : 89, batch_idx  : 40, triplet_loss : 0.1262314533509638
# epoch : 89, batch_idx  : 60, triplet_loss : 0.1261856737634245
# epoch : 89, batch_idx  : 80, triplet_loss : 0.12612808401361664
# epoch : 89, batch_idx  : 100, triplet_loss : 0.12609611050553104
# epoch : 89, batch_idx  : 120, triplet_loss : 0.12606449444492665
# epoch : 89, batch_idx  : 140, triplet_loss : 0.1260098828280745
# epoch : 89, batch_idx  : 160, triplet_loss : 0.12595032754009544
# epoch : 89, batch_idx  : 180, triplet_loss : 0.12588220781012222
# epoch : 89, batch_idx  : 200, triplet_loss : 0.12584402858120394
# epoch : 89, batch_idx  : 220, triplet_loss : 0.12577527003254918
# epoch : 89, batch_idx  : 240, triplet_loss : 0.12572205811236747
# epoch : 89, batch_idx  : 260, triplet_loss : 0.1257004584526354
# epoch : 89, batch_idx  : 280, triplet_loss : 0.12562576669048933
# epoch : 89, batch_idx  : 300, triplet_loss : 0.12559782126694563
# epoch : 90, batch_idx  : 20, triplet_loss : 0.12554132224967088
# epoch : 90, batch_idx  : 40, triplet_loss : 0.12547287415381495
# epoch : 90, batch_idx  : 60, triplet_loss : 0.12542116936959308
# epoch : 90, batch_idx  : 80, triplet_loss : 0.12533470099072683
# epoch : 90, batch_idx  : 100, triplet_loss : 0.12526545980842446
# epoch : 90, batch_idx  : 120, triplet_loss : 0.1252173778150211
# epoch : 90, batch_idx  : 140, triplet_loss : 0.12516826425428595
# epoch : 90, batch_idx  : 160, triplet_loss : 0.1251118322285495
# epoch : 90, batch_idx  : 180, triplet_loss : 0.12508446841395685
# epoch : 90, batch_idx  : 200, triplet_loss : 0.1250244414499348
# epoch : 90, batch_idx  : 220, triplet_loss : 0.12498345522937311
# epoch : 90, batch_idx  : 240, triplet_loss : 0.12495126214819094
# epoch : 90, batch_idx  : 260, triplet_loss : 0.12489742393296538
# epoch : 90, batch_idx  : 280, triplet_loss : 0.12486760942132583
# epoch : 90, batch_idx  : 300, triplet_loss : 0.12482872088601336
# epoch : 91, batch_idx  : 20, triplet_loss : 0.12476516005396322
# epoch : 91, batch_idx  : 40, triplet_loss : 0.12471141750196384
# epoch : 91, batch_idx  : 60, triplet_loss : 0.12465908125846907
# epoch : 91, batch_idx  : 80, triplet_loss : 0.12461868803593901
# epoch : 91, batch_idx  : 100, triplet_loss : 0.12456896710208737
# epoch : 91, batch_idx  : 120, triplet_loss : 0.12449226852368137
# epoch : 91, batch_idx  : 140, triplet_loss : 0.1244333488567976
# epoch : 91, batch_idx  : 160, triplet_loss : 0.1243948031440494
# epoch : 91, batch_idx  : 180, triplet_loss : 0.1243413717917537
# epoch : 91, batch_idx  : 200, triplet_loss : 0.12430336874221119
# epoch : 91, batch_idx  : 220, triplet_loss : 0.12423898271645786
# epoch : 91, batch_idx  : 240, triplet_loss : 0.1241827101875423
# epoch : 91, batch_idx  : 260, triplet_loss : 0.12411623126571215
# epoch : 91, batch_idx  : 280, triplet_loss : 0.12406104116356366
# epoch : 91, batch_idx  : 300, triplet_loss : 0.12401775438341743
# epoch : 92, batch_idx  : 20, triplet_loss : 0.12392867038067623
# epoch : 92, batch_idx  : 40, triplet_loss : 0.12386943410980684
# epoch : 92, batch_idx  : 60, triplet_loss : 0.12384391438796724
# epoch : 92, batch_idx  : 80, triplet_loss : 0.12378648505545349
# epoch : 92, batch_idx  : 100, triplet_loss : 0.12374333177694698
# epoch : 92, batch_idx  : 120, triplet_loss : 0.1236827452569299
# epoch : 92, batch_idx  : 140, triplet_loss : 0.12363736221869077
# epoch : 92, batch_idx  : 160, triplet_loss : 0.12357603808869888
# epoch : 92, batch_idx  : 180, triplet_loss : 0.12354576272112144
# epoch : 92, batch_idx  : 200, triplet_loss : 0.12348440913841123
# epoch : 92, batch_idx  : 220, triplet_loss : 0.12343321550760214
# epoch : 92, batch_idx  : 240, triplet_loss : 0.12336368481438201
# epoch : 92, batch_idx  : 260, triplet_loss : 0.12332652977733344
# epoch : 92, batch_idx  : 280, triplet_loss : 0.12326390121278112
# epoch : 92, batch_idx  : 300, triplet_loss : 0.12320216783553749
# epoch : 93, batch_idx  : 20, triplet_loss : 0.12308722974721874
# epoch : 93, batch_idx  : 40, triplet_loss : 0.12306873125359465
# epoch : 93, batch_idx  : 60, triplet_loss : 0.12301249529427899
# epoch : 93, batch_idx  : 80, triplet_loss : 0.12294938191463642
# epoch : 93, batch_idx  : 100, triplet_loss : 0.12287770542895693
# epoch : 93, batch_idx  : 120, triplet_loss : 0.12280779920768166
# epoch : 93, batch_idx  : 140, triplet_loss : 0.12279187179564845
# epoch : 93, batch_idx  : 160, triplet_loss : 0.122730461057621
# epoch : 93, batch_idx  : 180, triplet_loss : 0.1226605620141765
# epoch : 93, batch_idx  : 200, triplet_loss : 0.12261910968012045
# epoch : 93, batch_idx  : 220, triplet_loss : 0.1225515372036502
# epoch : 93, batch_idx  : 240, triplet_loss : 0.1224682905662806
# epoch : 93, batch_idx  : 260, triplet_loss : 0.12242024667806094
# epoch : 93, batch_idx  : 280, triplet_loss : 0.1223582819367516
# epoch : 93, batch_idx  : 300, triplet_loss : 0.122294823777832
# epoch : 94, batch_idx  : 20, triplet_loss : 0.1222172347065009
# epoch : 94, batch_idx  : 40, triplet_loss : 0.12218156935083176
# epoch : 94, batch_idx  : 60, triplet_loss : 0.12212567765483727
# epoch : 94, batch_idx  : 80, triplet_loss : 0.1220856052198277
# epoch : 94, batch_idx  : 100, triplet_loss : 0.122056960362234
# epoch : 94, batch_idx  : 120, triplet_loss : 0.12203434674621662
# epoch : 94, batch_idx  : 140, triplet_loss : 0.1219927869923306
# epoch : 94, batch_idx  : 160, triplet_loss : 0.12192799775821443
# epoch : 94, batch_idx  : 180, triplet_loss : 0.12187341168203206
# epoch : 94, batch_idx  : 200, triplet_loss : 0.12183365577899997
# epoch : 94, batch_idx  : 220, triplet_loss : 0.12181137317438495
# epoch : 94, batch_idx  : 240, triplet_loss : 0.12175457562078097
# epoch : 94, batch_idx  : 260, triplet_loss : 0.12170414015429061
# epoch : 94, batch_idx  : 280, triplet_loss : 0.12168049818217948
# epoch : 94, batch_idx  : 300, triplet_loss : 0.12163328695362009
# epoch : 95, batch_idx  : 20, triplet_loss : 0.1215542716541257
# epoch : 95, batch_idx  : 40, triplet_loss : 0.12149775811324165
# epoch : 95, batch_idx  : 60, triplet_loss : 0.12146672470971376
# epoch : 95, batch_idx  : 80, triplet_loss : 0.12139384072648977
# epoch : 95, batch_idx  : 100, triplet_loss : 0.12133478886946289
# epoch : 95, batch_idx  : 120, triplet_loss : 0.12129492666131407
# epoch : 95, batch_idx  : 140, triplet_loss : 0.12123866188391316
# epoch : 95, batch_idx  : 160, triplet_loss : 0.12118889703099055
# epoch : 95, batch_idx  : 180, triplet_loss : 0.12112681213896054
# epoch : 95, batch_idx  : 200, triplet_loss : 0.12109321662665232
# epoch : 95, batch_idx  : 220, triplet_loss : 0.1210299205172697
# epoch : 95, batch_idx  : 240, triplet_loss : 0.12100225673052958
# epoch : 95, batch_idx  : 260, triplet_loss : 0.12095126132618683
# epoch : 95, batch_idx  : 280, triplet_loss : 0.12089906875537126
# epoch : 95, batch_idx  : 300, triplet_loss : 0.12085190159603268
# epoch : 96, batch_idx  : 20, triplet_loss : 0.12079077377833874
# epoch : 96, batch_idx  : 40, triplet_loss : 0.1207354805041805
# epoch : 96, batch_idx  : 60, triplet_loss : 0.12069486574490444
# epoch : 96, batch_idx  : 80, triplet_loss : 0.12065307942474056
# epoch : 96, batch_idx  : 100, triplet_loss : 0.12059940318663981
# epoch : 96, batch_idx  : 120, triplet_loss : 0.12057916861357973
# epoch : 96, batch_idx  : 140, triplet_loss : 0.1205166692512941
# epoch : 96, batch_idx  : 160, triplet_loss : 0.120498343690003
# epoch : 96, batch_idx  : 180, triplet_loss : 0.12046053749416254
# epoch : 96, batch_idx  : 200, triplet_loss : 0.12042011713093795
# epoch : 96, batch_idx  : 220, triplet_loss : 0.12036530638612634
# epoch : 96, batch_idx  : 240, triplet_loss : 0.12029638791017594
# epoch : 96, batch_idx  : 260, triplet_loss : 0.1202771991937299
# epoch : 96, batch_idx  : 280, triplet_loss : 0.12021946535212345
# epoch : 96, batch_idx  : 300, triplet_loss : 0.120153487061491
# epoch : 97, batch_idx  : 20, triplet_loss : 0.12006721988727603
# epoch : 97, batch_idx  : 40, triplet_loss : 0.12001036741177822
# epoch : 97, batch_idx  : 60, triplet_loss : 0.11997428628793609
# epoch : 97, batch_idx  : 80, triplet_loss : 0.11994035299847264
# epoch : 97, batch_idx  : 100, triplet_loss : 0.11989268455257582
# epoch : 97, batch_idx  : 120, triplet_loss : 0.11986680397116774
# epoch : 97, batch_idx  : 140, triplet_loss : 0.11982130667828957
# epoch : 97, batch_idx  : 160, triplet_loss : 0.1197679095599726
# epoch : 97, batch_idx  : 180, triplet_loss : 0.11971966002262067
# epoch : 97, batch_idx  : 200, triplet_loss : 0.11971289203386958
# epoch : 97, batch_idx  : 220, triplet_loss : 0.11969541725537594
# epoch : 97, batch_idx  : 240, triplet_loss : 0.1196508989475376
# epoch : 97, batch_idx  : 260, triplet_loss : 0.11962254211292504
# epoch : 97, batch_idx  : 280, triplet_loss : 0.11961389035582756
# epoch : 97, batch_idx  : 300, triplet_loss : 0.11955504473092292
# epoch : 98, batch_idx  : 20, triplet_loss : 0.11951337295927626
# epoch : 98, batch_idx  : 40, triplet_loss : 0.11946297366999878
# epoch : 98, batch_idx  : 60, triplet_loss : 0.11942498097722701
# epoch : 98, batch_idx  : 80, triplet_loss : 0.11938641895020108
# epoch : 98, batch_idx  : 100, triplet_loss : 0.11933405714576695
# epoch : 98, batch_idx  : 120, triplet_loss : 0.11928273362405395
# epoch : 98, batch_idx  : 140, triplet_loss : 0.1192376774163663
# epoch : 98, batch_idx  : 160, triplet_loss : 0.11918392486481778
# epoch : 98, batch_idx  : 180, triplet_loss : 0.11914835152335496
# epoch : 98, batch_idx  : 200, triplet_loss : 0.11915421207150587
# epoch : 98, batch_idx  : 220, triplet_loss : 0.11912259723161431
# epoch : 98, batch_idx  : 240, triplet_loss : 0.11908467633708146
# epoch : 98, batch_idx  : 260, triplet_loss : 0.11903751142877855
# epoch : 98, batch_idx  : 280, triplet_loss : 0.11898613992134462
# epoch : 98, batch_idx  : 300, triplet_loss : 0.11895176567753707
# epoch : 99, batch_idx  : 20, triplet_loss : 0.11888507993340772
# epoch : 99, batch_idx  : 40, triplet_loss : 0.11885359644905151
# epoch : 99, batch_idx  : 60, triplet_loss : 0.11881382534273303
# epoch : 99, batch_idx  : 80, triplet_loss : 0.11877982888639568
# epoch : 99, batch_idx  : 100, triplet_loss : 0.11872087026615578
# epoch : 99, batch_idx  : 120, triplet_loss : 0.11870854293008554
# epoch : 99, batch_idx  : 140, triplet_loss : 0.11867352998210491
# epoch : 99, batch_idx  : 160, triplet_loss : 0.1186421392638996
# epoch : 99, batch_idx  : 180, triplet_loss : 0.11862769765353971
# epoch : 99, batch_idx  : 200, triplet_loss : 0.11861504769665887
# epoch : 99, batch_idx  : 220, triplet_loss : 0.11856744050804457
# epoch : 99, batch_idx  : 240, triplet_loss : 0.11853270266021584
# epoch : 99, batch_idx  : 260, triplet_loss : 0.11846652255353546
# epoch : 99, batch_idx  : 280, triplet_loss : 0.11840118423199773
# epoch : 99, batch_idx  : 300, triplet_loss : 0.11836120682998276

# %% [markdown]
# 데이터베이스(DB) 구축
# - 모델을 통해서 얻은 글로벌 기술자를 'train_feature_list'에 저장

# %%
from tqdm import tqdm

cluster_dataset = BerlinDataset(condition="cluster")
cluster_loader = torch.utils.data.DataLoader(cluster_dataset, batch_size=1,shuffle=False,num_workers=0) 

train_feature_list = list()

model.eval()

with torch.no_grad():
  for batch_idx, train_image in tqdm(enumerate(cluster_loader)) :
    output_train = model.encoder(train_image.cuda())
    # import pdb;pdb.set_trace()
    output_train = model.middle(train_image.unsqueeze(0),output_train)
    output_train = model.pool(output_train)##변경한부분
    train_feature_list.append(output_train.squeeze().detach().cpu().numpy())

train_feature_list = np.array(train_feature_list)
# Out:
# 314it [00:10, 31.38it/s]

# %% [markdown]
# Query 데이터에 대해서도 글로벌 기술자를 추출하여 'test_feature_list' 에 저장

# %%
test_dataset = BerlinDataset(condition="test")
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1,shuffle=False,num_workers=0)

# %%
test_feature_list = list()

with torch.no_grad():
  for batch_idx, test_image in tqdm(enumerate(test_loader)) :
    output_test = model.encoder(test_image.cuda())
    output_test = model.middle(test_image.unsqueeze(0),output_test)
    output_test = model.pool(output_test)##변경한부분
    test_feature_list.append(output_test.squeeze().detach().cpu().numpy())

test_feature_list = np.array(test_feature_list)
# Out:
# 280it [02:21,  1.98it/s]

# %% [markdown]
# Facebook에 제작한 faiss 라이브러리 사용하여 글로벌 기술자 벡터간의 유사도 계산

# %%
import faiss

n_values = [1,5,10,20]

faiss_index = faiss.IndexFlatL2(train_feature_list.shape[1])
faiss_index.add(train_feature_list)
_, predictions = faiss_index.search(test_feature_list, max(n_values))

# %% [markdown]
# 쿼리에서 추출한 글로벌 기술자에 대해서 유사도가 높은 상위 20개의 데이터 베이스 인덱스를 저장하여 json으로 제작 (이를 EvalAI에 제출)

# %%
import json

file_path = "./idea_submit2.json"

data = {}
data['Query'] = list()

for i in range(len(predictions)) :
  data_t = [("id",i),("positive",predictions[i].tolist())]
  data_t = dict(data_t)
  data['Query'].append(data_t)
  
with open(file_path, 'w') as outfile:
    json.dump(data, outfile, indent=4)

# %%
pwd
# Out:
# '/content/drive/MyDrive/2022_CV/NetVLAD'

# %%
# !du -sh
# Out:
# 6.5G	.
